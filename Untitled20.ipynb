# %%
import json, sys, random, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import PIL
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from PIL import Image, ImageDraw
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from os import listdir
import time
import math
import shutil
from tqdm import tqdm
from tensorflow.keras.preprocessing import image

# %%
import zipfile
import os
file_zip_path = '/content/archive (1).zip'

def extract_zip(zip_path, extract_to):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
file_dir = '/content/train'
extract_zip(file_zip_path, file_dir)

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)
train = train_datagen.flow_from_directory(
        '/content/train/dataset/train',
        target_size=(400, 400),
        batch_size=32,
        class_mode='binary')
test = test_datagen.flow_from_directory(
        '/content/train/dataset/test',
        target_size=(400, 400),
        batch_size=32,
        class_mode='binary')
validation = val_datagen.flow_from_directory(
        '/content/train/dataset/valid',
        target_size=(400, 400),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 2800 images belonging to 2 classes.
# Found 0 images belonging to 0 classes.
# Found 200 images belonging to 2 classes.

# %%
plt.imshow(plt.imread("/content/train/dataset/test/N1.jpeg"))

# %%
# !pip install imutils

# %%
train_labels = train.classes
print("Training class distribution:", np.unique(train_labels, return_counts=True))
val_labels = validation.classes
print("Validation class distribution:", np.unique(val_labels, return_counts=True))
# Out:
# Training class distribution: (array([0, 1], dtype=int32), array([1400, 1400]))
# Validation class distribution: (array([0, 1], dtype=int32), array([100, 100]))

# %%
IMG_SIZE = (224,224)
import imutils
img = cv2.imread('/content/train/dataset/test/N2.jpeg')
img = cv2.resize(
            img,
            dsize=IMG_SIZE,
            interpolation=cv2.INTER_CUBIC
        )
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray = cv2.GaussianBlur(gray, (5, 5), 0)


thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
thresh = cv2.erode(thresh, None, iterations=2)
thresh = cv2.dilate(thresh, None, iterations=2)

cnts=cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts= imutils.grab_contours(cnts)
c=max(cnts, key=cv2.contourArea)

extLeft=tuple(c[c[:,:,0].argmin()][0])
extRight=tuple(c[c[:,:,0].argmax()][0])
extTop=tuple(c[c[:,:, 1].argmin()][0])
extBot=tuple(c[c[:,:, 1].argmax()][0])


img_cnt=cv2.drawContours(img.copy(), [c], -1, (0, 255, 255), 4)
img_pnt=cv2.circle(img_cnt.copy(), extLeft, 8, (0,0,255), -1)
img_pnt=cv2.circle(img_pnt, extRight, 8, (0,255,0),-1)
img_pnt=cv2.circle(img_pnt, extTop, 8, (255, 0, 0), -1)
img_pnt = cv2.circle(img_pnt, extBot, 8, (255, 255, 0), -1)


ADD_PIXELS = 0
new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()

# %%
plt.figure(figsize=(15,6))
plt.subplot(141)
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.title('Step 1. Get the original image')
plt.subplot(142)
plt.imshow(img_cnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 2. Find the biggest contour')
plt.subplot(143)
plt.imshow(img_pnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 3. Find the extreme points')
plt.subplot(144)
plt.imshow(new_img)
plt.xticks([])
plt.yticks([])
plt.title('Step 4. Crop the image')
plt.show()

# %%
es = EarlyStopping(monitor='val_accuracy',min_delta= 0.01,patience= 5,verbose= 1,mode='auto')

# %%
model=Sequential()

model.add(Conv2D(filters=32, kernel_size= (3,3),activation= 'relu',input_shape=(400, 400,3)) )

model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu' ))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu' ))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu' ))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Flatten())
model.add(Dense(units=512, activation='relu'))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(loss= "binary_crossentropy", optimizer='adam', metrics=['accuracy'] )

model.summary()
Model
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 398, 398, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 396, 396, 32)        │           9,248 │
# ...

# %%
es = EarlyStopping(monitor='val_accuracy', min_delta=0.01, patience=2, verbose=2, mode='auto')
mc = ModelCheckpoint(filepath="/content/training_set/bestmodelh5.keras", monitor='val_accuracy', save_best_only=True)

# %%
model.fit(x=train,validation_data=validation,epochs=4,callbacks = [mc,es], steps_per_epoch=40)
# Out:
# Epoch 1/4
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1067s 26s/step - accuracy: 0.5954 - loss: 1.7804 - val_accuracy: 0.7200 - val_loss: 0.6047
# Epoch 2/4
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1017s 25s/step - accuracy: 0.7735 - loss: 0.4876 - val_accuracy: 0.7650 - val_loss: 0.5148
# Epoch 3/4
#  8/40 ━━━━━━━━━━━━━━━━━━━━ 12:40 24s/step - accuracy: 0.8036 - loss: 0.4380
# ...

# %%
pd.DataFrame(model.history.history)
# Out:
#    accuracy      loss  val_accuracy  val_loss
# 0  0.660937  0.995905         0.720  0.604740
# 1  0.771361  0.477771         0.765  0.514841
# 2  0.750000  0.514330         0.620  0.590920
# 3  0.806250  0.431575         0.725  0.556765

# %%
import seaborn as sns
sns.set_style("darkgrid")
plt.figure(figsize=(12,10))
pd.DataFrame(model.history.history).plot(figsize=(15,8))
# Out:
# <Axes: >

# %%
def predictor(location):
    test_image=image.load_img(location,target_size=(400,400))
    test_image=image.img_to_array(test_image)
    test_image=np.expand_dims(test_image, axis=0)
    result=model.predict(test_image)

    if result[0][0] == 0:

        prediction = "The MRI image has no brain tumor"
    else:
        prediction = "The MRI image has BRAIN TUMOR"
    print(result[0][0])
    return prediction

# %%
plt.imshow(plt.imread("/content/train/dataset/valid/yes/y1400.jpg"))

# %%
predictor("/content/train/dataset/valid/yes/y1400.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# 1.0
# 'The MRI image has BRAIN TUMOR'

# %%
import PIL
fig, axs = plt.subplots(2, 5, figsize=(20, 10))
lst = ["/content/train/dataset/valid/yes/y1400.jpg",
       "/content/train/dataset/valid/yes/y1404.jpg",
       "/content/train/dataset/valid/yes/y1407.jpg",
       "/content/train/dataset/valid/yes/y1415.jpg",
       "/content/train/dataset/valid/yes/y1429.jpg",
       "/content/train/dataset/valid/yes/y1437.jpg",]


axs[0][0].title.set_text(predictor(lst[0]))
axs[0][0].imshow(PIL.Image.open(lst[0]))
axs[0][1].title.set_text(predictor(lst[1]))
axs[0][1].imshow(PIL.Image.open(lst[1]))
axs[0][2].title.set_text(predictor(lst[2]))
axs[0][2].imshow(PIL.Image.open(lst[2]))
axs[0][3].title.set_text(predictor(lst[3]))
axs[0][3].imshow(PIL.Image.open(lst[3]))
axs[0][4].title.set_text(predictor(lst[4]))
axs[0][4].imshow(PIL.Image.open(lst[4]))
axs[1][0].title.set_text(predictor(lst[5]))
axs[1][0].imshow(PIL.Image.open(lst[5]))



fig.tight_layout()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 0.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1.0
